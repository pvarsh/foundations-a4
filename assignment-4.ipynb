# %%
import os
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %matplotlib inline

# %% [markdown]
# # Description of the data and cleaning
#
# ## Data files
# * **R10842464_SL050.csv**
#     * Folder: counties_census_2000_social_explorer
#     * From: Social explorer
#     * Year 2000
#     * Relevant variables
#         * Geo_FIPS (county)
#         * Total Population
#         * Urban Population
#         * Area (Total)
#         * Area (Land)
# * **CountiesBySector.v2.2.web.xls** manually converted to **CountiesBySector.csv**
#     * Folder: vulcan_county_CO2_2000
#     * From: Vulcan project
#     * Year: 2002
#     * Relevant variables
#         * FIPS (county)
#         * Total (CO2 emissions in Million Tonnes)
#         * Commercial, Industrial, Residential, etc. emissions
# * **tab01_oritinal.xls**
#     * Folder: MSA_county_2000
#     * From: census.gov
#     * Year: 2000
#     * Relevant variables
#         * MSA/CMSA Code
#         * FIPS State/County Code
#         * Census population

# %%
dataPath = "../data"
os.listdir(dataPath)
# Out:
# ['.DS_Store',
#  'counties_census_2000_social_explorer',
#  'MSA_county_2000',
#  'vulcan_county_CO2_2000',
#  'zips_and_unused_data']

# %% [markdown]
# ###### Population and area data from social explorer

# %%
folder = "counties_census_2000_social_explorer"
fname = "R10842464_SL050.csv"
fileIn = dataPath + '/' + folder + '/' + fname

### Read two header lines and build dictionary from first to second
with open(fileIn) as f:
    reader = csv.reader(f)
    line1 = reader.next()
    line2 = reader.next()
    headerDict = {line1[i]: line2[i] for i in range(len(line2))}

variablesToKeep = ['FIPS', 'Total Population', 'Urban', 'Population Density (per sq. mile)', 'Area Total', 'Area (Land)']

### read into DataFrame
with open(fileIn, 'r') as f:
    demograph = pd.read_csv(f, header = 1)

### rename columns using first header
demograph.columns = line1

### drop many columns
demograph = demograph[variablesToKeep]

### rename remaining columns
demograph.columns = [u'county_FIPS',
                     u'Total Population',
                     u'Total Population',
                     u'pop_total',
                     u'pop_urban',
                     u'pop_density',
                     u'total_area',
                     u'Area (Land)',
                     u'Area (Land)',
                     u'land_area']

### drop redundant columns
demograph.drop([u'Total Population', u'Area (Land)'], axis = 1, inplace = True)
demograph
# Out:
#       county_FIPS  pop_total  pop_urban  pop_density  total_area   land_area
# 0            1001      43671      24101     73.27742   604.44650   595.96800
# 1            1003     140415      64337     87.96021  2026.92900  1596.34700
# 2            1005      29038       8280     32.81487   904.51740   884.90360
# 3            1007      20826       3863     33.42723   626.16190   623.02500
# 4            1009      51024       4578     79.03527   650.60410   645.58520
# 5            1011      11714       4139     18.74202   626.05630   625.01260
# 6            1013      21399       5388     27.54525   777.92220   776.86720
# 7            1015     112249      77476    184.48010   612.32100   608.46140
# 8            1017      36583      18374     61.26085   603.10680   597.16770
# 9            1019      23988          0     43.36847   599.95150   553.12080
# 10           1021      39593       4765     57.05218   700.75600   693.97880
# 11           1023      15922          0     17.42940   920.84950   913.51390
# 12           1025      27867       7090     22.50287  1252.50500  1238.37500
# 13           1027      14254          0     23.55745   606.00180   605.07400
# 14           1029      14123          0     25.21013   561.01810   560.21120
               u'commercial',
               u'industrial',
               u'residential',
               u'electricity_prod',
               u'onroad',
               u'cement',
               u'aircraft',
               u'airborne',
               u'nonroad']

### convert co2 output into tonnes
co2['co2_total'] = co2.co2_total_mln_t * 1e6

# %% [markdown]
# ###### County to MSA

# %%
folder = "MSA_county_2000"
fname = "tab01.csv"
fileIn = dataPath + '/' + folder + '/' + fname

with open(fileIn, 'r') as f:
    MSA_county = pd.read_csv(f, dtype = str)
    
### drop columns
MSA_county = MSA_county[['MSA/ CMSA Code', u'FIPS State/ County Code']]
MSA_county.columns = ['msa_code', 'county_FIPS']

# remove empty rows
MSA_county = MSA_county[pd.notnull(MSA_county.iloc[:, 1])]

### convert county_FIPS to np.int64 to match demograph and co2 tables
MSA_county['county_FIPS'] = MSA_county['county_FIPS'].astype(np.int64)

### group by county
grouped = MSA_county.groupby('county_FIPS')
countyToMSA = grouped.first()
countyToMSA['county_FIPS'] = countyToMSA.index

# %% [markdown]
# ###### Table summaries

# %%
print "### demograph ###"
print demograph.shape
print demograph.columns
print demograph.dtypes

print "\n### co2 ###"
print co2.shape
print co2.columns
print co2.dtypes

print "\n### countyToMSA ###"
print countyToMSA.shape
print countyToMSA.columns
print countyToMSA.dtypes
# Out:
# ### demograph ###
# (3219, 6)
# Index([u'county_FIPS', u'pop_total', u'pop_urban', u'pop_density', u'total_area', u'land_area'], dtype='object')
# county_FIPS      int64
# pop_total        int64
# pop_urban        int64
# pop_density    float64
# total_area     float64
# land_area      float64
# dtype: object
#
# ### co2 ###
# (3141, 12)
# Index([u'county_FIPS', u'co2_total_mln_t', u'commercial', u'industrial', u'residential', u'electricity_prod', u'onroad', u'cement', u'aircraft', u'airborne', u'nonroad', u'co2_total'], dtype='object')
# county_FIPS           int64
# co2_total_mln_t     float64
# commercial          float64
# industrial          float64
# residential         float64
# electricity_prod    float64
# onroad              float64
# cement              float64
# aircraft            float64
# airborne            float64
# nonroad             float64
# co2_total           float64
# dtype: object
#
# ### countyToMSA ###
# (907, 2)
# Index([u'msa_code', u'county_FIPS'], dtype='object')
# msa_code       object
# county_FIPS     int64
# dtype: object

# %%
### Temporary demographic and co2 join

demo_co2 = pd.merge(demograph, co2, how = 'inner', on = 'county_FIPS')
demo_co2.shape
demo_co2.head()

### Joining temporary table above with county_MSA table and aggregating by MSA
demo_co2_with_MSA = pd.merge(demo_co2, countyToMSA, how = 'inner', on = 'county_FIPS')
grouped = demo_co2_with_MSA.groupby(['msa_code'])
mt = grouped.sum()
mt.drop(['pop_density', 'county_FIPS'], axis = 1, inplace = True) # after summing, these variables are meaningless

### Dropping MSAs with total population < 100,000
mt = mt[mt.pop_total > 1e5]

mt.head()
# Out:
#           pop_total  pop_urban  total_area  land_area  co2_total_mln_t  \
# msa_code
# 0040         126555     109658    919.2518   915.6259         0.382555
# 0120         120822      95450    696.6477   685.3690         0.849188
# 0160         875583     675087   3288.6157  3222.1941         3.002046
# 0200         712738     654512   5951.1820  5943.0000         2.141536
# 0220         126337      78504   1361.9620  1322.5410         1.561100
#
#           commercial  industrial  residential  electricity_prod    onroad  \
# msa_code
# 0040        0.022338    0.015469     0.027425          0.000000  0.249408
# 0120        0.014966    0.423332     0.016791          0.184750  0.169383
# 0160        0.226240    0.190203     0.464706          0.264052  1.363584
# 0200        0.166847    0.103907     0.276234          0.209940  1.030404
# 0220        0.014420    0.123136     0.024119          1.081273  0.263871
#
#             cement  aircraft  airborne   nonroad    co2_total
# msa_code
# 0040      0.000000  0.015101  0.037960  0.014855   382555.269
# 0120      0.000000  0.007027  0.017663  0.015276   849188.185
# 0160      0.238136  0.043270  0.108768  0.103087  3002046.246
# 0200      0.040301  0.064095  0.161114  0.088695  2141536.236
# 0220      0.000000  0.011238  0.028250  0.014791  1561100.194

# %% [markdown]
# ## Plots

# %% [markdown]
# ###### Total population against total CO2 emissions

# %%
fig1, ax1 = plt.subplots(num = 1, figsize = (10, 6)) 

# Title and axis labels
fig1.suptitle('Total population and CO2 emissions for MSAs', fontsize = 14)
ax1.set_xlabel('log population')
ax1.set_ylabel('log total emissions')

### Scatter
ax1.scatter(np.log(mt.pop_total),
            np.log(mt.co2_total),
            c = "dodgerblue",
            lw = 0,
            s = 30,
            alpha = 0.8,
            label = "MSA")

### Get x and y lims
xmin, xmax = ax1.get_xlim()
ymin, ymax = ax1.get_ylim()

### Regression
# Design matrix
y = np.log(mt.co2_total)
ones = np.ones(mt.shape[0])
X = np.column_stack((ones, np.log(mt.pop_total)))

# Fit model
mod1 = sm.OLS(y, X).fit()
print mt.shape[0]
print mod1.params

### Plot regression line
x = np.linspace(xmin, xmax)
y = mod1.params[0] + mod1.params[1] * x
regression_label = r'$\beta_1 = %2.2f$' %mod1.params[1]
ax1.plot(x, y, c = 'darkorange', lw = 2, label = regression_label)

# Set x and y lims
ax1.set_xlim(xmin, xmax)
ax1.set_ylim(ymin, ymax)

# Legend
ax1.legend(loc = 2)

# Show
plt.show()
# Out:
# 259
# const    2.584958
# x1       0.919897
# dtype: float64

# %%
### Regression
# Design matrix
y = np.log(mt.pop_total)
ones = np.zeros(mt.shape[0])
X = np.column_stack((ones, np.log(mt.co2_total)))
# Fit model
mod1 = sm.OLS(y, X).fit()

# %%
print mod1.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              pop_total   R-squared:                       0.732
# Model:                            OLS   Adj. R-squared:                  0.731
# Method:                 Least Squares   F-statistic:                     703.6
# Date:                Fri, 21 Nov 2014   Prob (F-statistic):           1.52e-75
# Time:                        15:51:23   Log-Likelihood:                -218.81
# No. Observations:                 259   AIC:                             441.6
# Df Residuals:                     257   BIC:                             448.7
# Df Model:                           1
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const          1.3763      0.434      3.175      0.002         0.523     2.230
# x1             0.7963      0.030     26.526      0.000         0.737     0.855
# ==============================================================================
# Omnibus:                       42.374   Durbin-Watson:                   1.911
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):